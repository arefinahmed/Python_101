# %%
game=[[0,0,0],[0,0,0],[0,0,0]]

 


    
def game_board(game_map,player=0,row=0,column=0,just_display=False):
    try:
        print('   1',' 2', ' 3') 
        if not just_display:
            game_map[row][column]=player
        for row,column in enumerate(game):
            print(row, column)
            row+=1
        return game_map
    except IndexError as e: 
        print(" you might input row/column out of range",e)
    except Exception as e:
        print("something went wrong", e)
    


game=game_board(game,just_display=True) # showing the game board
game=game_board(game_board,player=1,row=1,column=3)
print("Enter the first player turn")

#game[0][0]=1

print('\n')
# Out:
#    1  2  3
# 0 [0, 0, 0]
# 1 [0, 0, 0]
# 2 [0, 0, 0]
#    1  2  3
# something went wrong 'function' object is not subscriptable
# Enter the first player turn
